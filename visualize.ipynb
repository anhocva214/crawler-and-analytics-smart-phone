# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data_phone_nguyen_kiem_preprocessed.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#      brand                      name  ratting  ratting_total  price_sale  \
# 0  Samsung   Samsung Galaxy A52 4G        5.0              1     7390000
# 1  Samsung   Samsung Galaxy A32 4G        0.0              0     5420000
# 2  Samsung   Samsung Galaxy A52 4G        5.0              1     7390000
# 3  Samsung   Samsung Galaxy S20 FE        0.0              0    12990000
# 4  Samsung   Samsung Galaxy A32 4G        0.0              0     5420000
#
#    price_origin status                     Model Màu sắc Nhà sản xuất  \
# 0       9290000    Mới               SM-A525F/DS    Xanh      Samsung
# 1       6490000    Mới               SM-A325F/DS    Xanh      Samsung
# 2       9290000    Mới               SM-A525F/DS     Đen      Samsung
# 3      15490000    Mới  GALAXYS20F (SM-G780F/DS)    Xanh      Samsung
# 4       6490000    Mới               SM-A325F/DS     Đen      Samsung
#
#     Xuất xứ Thời gian bảo hành Địa điểm bảo hành  \
# 0  Việt Nam           12 tháng        Nguyễn Kim
# ...

# %%
df_top = df.copy()
df_top = df_top.drop_duplicates(subset=['name'], keep='last')
df_top
# Out:
#        brand                            name  ratting  ratting_total  \
# 2    Samsung         Samsung Galaxy A52 4G        5.0              1
# 4    Samsung         Samsung Galaxy A32 4G        0.0              0
# 5    Samsung         Samsung Galaxy S20 FE        0.0              0
# 8       Oppo                      OPPO A15s       0.0              0
# 10      Oppo                       OPPO A15       0.0              0
# 11      Oppo        OPPO Reno4 Xanh thiên hà      0.0              0
# 14   Samsung    Samsung Galaxy S21 Plus 5G        5.0              1
# 18   Samsung            Samsung Galaxy A12        0.0              0
# 22   Samsung        Samsung Galaxy A52s 5G        0.0              0
# 26      Oppo                     OPPO A16K        0.0              0
# 28      Oppo                      OPPO A55        0.0              0
# 31      Vivo                     Vivo V23e        0.0              0
# 32      Vivo             Vivo Y15s  Xanh Đen      0.0              0
# ...
